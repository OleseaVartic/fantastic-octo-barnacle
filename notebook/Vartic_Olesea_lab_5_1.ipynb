# %% [markdown]
# **Lab 6 Assignment: Producing Publication-Ready Figures**

# %%
import seaborn as sns
import pandas as pd
import matplotlib.pyplot as plt

lab3_data = sns.load_dataset('titanic')
lab3_data.loc[(lab3_data['who'] == 'child') & (lab3_data['sex'] == 'male'), 'who'] = 'boy'
lab3_data.loc[(lab3_data['who'] == 'child') & (lab3_data['sex'] == 'female'), 'who'] = 'girl'
lab3_data.loc[lab3_data['survived'] == 0, 'survived_str'] = 'no'
lab3_data.loc[lab3_data['survived'] == 1,  'survived_str'] = 'yes'

# %%
sns.set_style("white")
sns.set_context("paper")

# %%
palette = {'man':'blue','woman':'tab:orange','boy':'cornflowerblue','girl':'sandybrown'}

# %% [markdown]
# **Plot #1**

# %%
sns.barplot(data=lab3_data, x='class', y='survived', hue='who', capsize=0.05, errorbar=('ci', 90), palette=palette)
# Out:
# <Axes: xlabel='class', ylabel='survived'>

# %%
lab3_data_filtered = lab3_data[lab3_data['class'] != 'Second']

# %%
lab3_data_filtered.loc[:, 'class'] = pd.Categorical(lab3_data_filtered['class'], categories=['First', 'Third'])

# %%
palette = {'man':'blue','woman':'tab:orange','boy':'cornflowerblue','girl':'sandybrown'}

# %%
sns.barplot(data=lab3_data_filtered, x='class', y='survived', hue='who', capsize=0.05, errorbar=('ci', 90), palette=palette)
# Out:
# <Axes: xlabel='class', ylabel='survived'>

# %%
lab3_data_filtered = lab3_data[lab3_data['class'] != 'Second']

# %%
lab3_data_filtered.loc[:, 'class'] = pd.Categorical(lab3_data_filtered['class'], categories=['First', 'Third'])

# %%
palette = {'man':'blue','woman':'tab:orange','boy':'cornflowerblue','girl':'sandybrown'}

# %%
sns.barplot(data=lab3_data_filtered, x='class', y='survived', hue='who', capsize=0.05, errorbar=('ci', 90), palette=palette)
# Out:
# <Axes: xlabel='class', ylabel='survived'>

# %%
lab3_data['survived_str'] = lab3_data['survived'].map({0: 'no', 1: 'yes'})
sns.barplot(data=lab3_data_filtered, x='class', y='survived', hue='who', capsize=0.05, palette=palette)
plt.xlabel('Boarding Class')
plt.ylabel('Mean survival rate')
# Out:
# Text(0, 0.5, 'Mean survival rate')

# %%
sns.despine()

# %% [markdown]
# **Plot #2**

# %%
palette = {'white'}
sns.boxplot(data=lab3_data, x='survived', y='age', hue='who', palette=palette)
# Out:
# <Axes: xlabel='survived', ylabel='age'>

# %%
import seaborn as sns
import pandas as pd
import matplotlib.pyplot as plt

lab3_data = sns.load_dataset('titanic')

lab3_data.loc[(lab3_data['who'] == 'child') & (lab3_data['sex'] == 'male'), 'who'] = 'boy'
lab3_data.loc[(lab3_data['who'] == 'child') & (lab3_data['sex'] == 'female'), 'who'] = 'girl'

lab3_data.loc[lab3_data['survived'] == 0, 'survived_str'] = 'no'
lab3_data.loc[lab3_data['survived'] == 1, 'survived_str'] = 'yes'

sns.set_style("white")
sns.set_context("paper")

palette = {'man': 'blue', 'woman': 'tab:orange', 'boy': 'cornflowerblue', 'girl': 'sandybrown'}

sns.stripplot(data=lab3_data, x='survived', y='age', hue='who', jitter=0.3, alpha=0.5, dodge=True, palette=palette)

plt.xlabel('Survived')
plt.ylabel('Age')
plt.title('Age vs. Survival Status by Who')

plt.show()

# %%
import seaborn as sns
import pandas as pd
import matplotlib.pyplot as plt

import seaborn as sns
import pandas as pd
import matplotlib.pyplot as plt

lab3_data = sns.load_dataset('titanic')

lab3_data.loc[(lab3_data['who'] == 'child') & (lab3_data['sex'] == 'male'), 'who'] = 'boy'
lab3_data.loc[(lab3_data['who'] == 'child') & (lab3_data['sex'] == 'female'), 'who'] = 'girl'

lab3_data.loc[lab3_data['survived'] == 0, 'survived_str'] = 'no'
lab3_data.loc[lab3_data['survived'] == 1, 'survived_str'] = 'yes'

sns.set_style("white")
sns.set_context("paper")

boxplot_palette = {'man': 'white', 'woman': 'white', 'boy': 'white', 'girl': 'white'}

axes2 = sns.boxplot(data=lab3_data, x='survived', y='age', hue='who', palette=boxplot_palette, showfliers=False)

stripplot_palette = {'man': 'blue', 'woman': 'tab:orange', 'boy': 'cornflowerblue', 'girl': 'sandybrown'}

sns.stripplot(data=lab3_data, x='survived', y='age', hue='who', jitter=0.3, alpha=0.5, dodge=True, palette=stripplot_palette, ax=axes2)

handles, labels = axes2.get_legend_handles_labels()
plt.legend(handles[4:8], labels[4:8], title='Who')

axes2.set(xlabel='Survived', ylabel='Age')
plt.title('Age vs. Survival Status by Who')

plt.show()

# %%
import seaborn as sns
import pandas as pd
import matplotlib.pyplot as plt

lab3_data = sns.load_dataset('titanic')

lab3_data.loc[(lab3_data['who'] == 'child') & (lab3_data['sex'] == 'male'), 'who'] = 'boy'
lab3_data.loc[(lab3_data['who'] == 'child') & (lab3_data['sex'] == 'female'), 'who'] = 'girl'

lab3_data.loc[lab3_data['survived'] == 0, 'survived_str'] = 'no'
lab3_data.loc[lab3_data['survived'] == 1, 'survived_str'] = 'yes'

sns.set_style("white")
sns.set_context("paper")

boxplot_palette = {'man': 'white', 'woman': 'white', 'boy': 'white', 'girl': 'white'}

axes2 = sns.boxplot(data=lab3_data, x='survived', y='age', hue='who', palette=boxplot_palette, zorder=5)

stripplot_palette = {'man': 'blue', 'woman': 'tab:orange', 'boy': 'cornflowerblue', 'girl': 'sandybrown'}

sns.stripplot(data=lab3_data, x='survived', y='age', hue='who', jitter=0.3, alpha=0.5, dodge=True, palette=stripplot_palette, zorder=0, ax=axes2)

plt.xlabel('Survived')
plt.ylabel('Age')

sns.despine()

handles, labels = axes2.get_legend_handles_labels()
plt.legend(handles[4:8], labels[4:8], title='Who')

axes2.set(xlabel='Survived', ylabel='Age')
plt.title('Age vs. Survival Status by Who')

plt.show()

# %% [markdown]
# **Plot #3**

# %%
import seaborn as sns
import pandas as pd
import matplotlib.pyplot as plt

lab3_data = sns.load_dataset('titanic')

lab3_data.loc[(lab3_data['who'] == 'child') & (lab3_data['sex'] == 'male'), 'who'] = 'boy'
lab3_data.loc[(lab3_data['who'] == 'child') & (lab3_data['sex'] == 'female'), 'who'] = 'girl'

lab3_data.loc[lab3_data['survived'] == 0, 'survived_str'] = 'no'
lab3_data.loc[lab3_data['survived'] == 1, 'survived_str'] = 'yes'

sns.set_style("white")
sns.set_context("paper")

palette = {'man': 'blue', 'woman': 'tab:orange', 'boy': 'cornflowerblue', 'girl': 'sandybrown'}

sns.violinplot(data=lab3_data, x='survived_str', y='age', hue='who', palette=palette, split=True)

plt.xlabel('Survived')
plt.ylabel('Age')
plt.title('Age vs. Survival Status by Who')

sns.despine()

plt.show()

# %% [markdown]
# **Plot #4**

# %%
import seaborn as sns
import matplotlib.pyplot as plt

lab3_data = sns.load_dataset('titanic')

sns.set_style("white")
sns.set_context("paper")

palette = {'First': 'blue', 'Second': 'orange', 'Third': 'green'}

plt.figure(figsize=(10, 6))
scatter_plot = sns.scatterplot(data=lab3_data, x='age', y='fare', hue='class', palette=palette)

plt.xlabel('Age')
plt.ylabel('Fare')
plt.title('Scatter Plot of Age vs. Fare by Class')

sns.despine()

plt.show()

# %% [markdown]
# **Plot #5**

# %%
lab3_data_subset=lab3_data[['class','who','fare']]
lab3_data_subset=lab3_data_subset.dropna(how='any')
lab3_data_subsetAverage=lab3_data_subset.groupby(['class','who']).mean()
lab3_data_subsetAverage=lab3_data_subsetAverage.reset_index()
lab3_data_subsetAverage.head()
# Out:
#     class    who        fare
# 0   First  child  139.382633
# 1   First    man   65.951086
# 2   First  woman  104.317995
# 3  Second  child   28.323905
# 4  Second    man   19.054124

# %%
import pandas as pd
import seaborn as sns
import matplotlib.pyplot as plt

lab3_data_subset = lab3_data[['class', 'who', 'fare']]
lab3_data_subset = lab3_data_subset.dropna(how='any')

lab3_data_subsetAverage = lab3_data_subset.groupby(['class', 'who']).mean().reset_index()

matrix_data = lab3_data_subsetAverage.pivot_table(index='class', columns='who', values='fare', aggfunc='mean')

plt.figure(figsize=(10, 6))
axes5 = sns.heatmap(data=matrix_data, annot=True, fmt='.2f', cmap='coolwarm')

for text in axes5.texts:
    text.set_text('£' + text.get_text())

axes5.set(xlabel='Demographic', ylabel='Boarding Class')

tick_labels = matrix_data.columns.tolist()
axes5.set_xticklabels(tick_labels)

plt.show()
